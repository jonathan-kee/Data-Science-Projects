# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_url = "postgresql+psycopg2://postgres:abc123@localhost/prosperous_universe"
engine = create_engine(db_url)

# %%
query = """
    SELECT *
    FROM raw.recipe_report;
"""

# %%
with engine.connect() as connection:
    df = pd.read_sql_query(query, con=connection)

# %%
df
# Out:
#                    original_query prefix Output_Material  volume  \
# 0   SME:6xALO-1xO-1xC-1xFLX=>4xAL    SME              AL     4.0
# 1         SME:6xALO-1xC-1xO=>3xAL    SME              AL     3.0
# 2              SME:1xSCR-1xO=>6xS    SME               S     6.0
# 3      SME:5xCUO-10xO-1xSIO=>3xCU    SME              CU     3.0
# 4             SME:1xC-3xAUO=>2xAU    SME              AU     2.0
# 5   SME:6xFEO-1xC-1xO-1xFLX=>4xFE    SME              FE     4.0
# 6         SME:6xFEO-1xC-1xO=>3xFE    SME              FE     3.0
# 7          SME:10xLIO-4xHAL=>4xLI    SME              LI     4.0
# 8         SME:4xTIO-1xC-1xO=>2xTI    SME              TI     2.0
# 9         SME:3xSIO-1xC-1xO=>1xSI    SME              SI     1.0
# 10           SME:3xSIO-1xAL=>1xSI    SME              SI     1.0
# 11            SME:2xFE-8xO=>2xSTL    SME             STL     2.0
# 12   SME:4xTIO-1xC-1xO-1xNA=>2xTI    SME              TI     2.0
# 13  SME:3xSIO-1xC-1xO-1xFLX=>1xSI    SME              SI     1.0
# 14        SME:4xAL-1xSI-2xO=>1xCF    SME              CF     1.0
# 15  SME:8xREO-1xC-1xO-1xFLX=>5xRE    SME              RE     5.0
# 16        SME:8xREO-1xC-1xO=>4xRE    SME              RE     4.0
# 17        SME:4xTS-1xO-1xAL=>1xSI    SME              SI     1.0
#
#     input_materials_AI1_AskPrice_per_unit  total input_materials_AI1_AskPrice  \
# 0                              889.500000                              3558.0
# 1                              995.333333                              2986.0
# 2                              169.333333                              1016.0
# 3                             1789.333333                              5368.0
# 4                             2945.000000                              5890.0
# 5                             1318.500000                              5274.0
# 6                             1567.333333                              4702.0
# 7                             2608.000000                             10432.0
# 8                             4293.000000                              8586.0
# 9                             3640.000000                              3640.0
# 10                            3354.000000                              3354.0
# 11                            3164.000000                              6328.0
# 12                            4293.000000                              8586.0
# 13                            4212.000000                              4212.0
# 14                           16772.000000                             16772.0
# 15                            7047.600000                             35238.0
# 16                            8666.500000                             34666.0
# 17                           10108.000000                             10108.0
#
#     total output_materials_AI1_BidPrice  profit of buy minus sell  \
# 0                                5200.0                    1642.0
# 1                                3900.0                     914.0
# 2                                1200.0                     184.0
# 3                                5430.0                      62.0
# 4                                5400.0                    -490.0
# 5                                4200.0                   -1074.0
# 6                                3150.0                   -1552.0
# 7                                7360.0                   -3072.0
# 8                                4100.0                   -4486.0
# 9                                2350.0                   -1290.0
# 10                               2350.0                   -1004.0
# 11                               3620.0                   -2708.0
# 12                               4100.0                   -4486.0
# 13                               2350.0                   -1862.0
# 14                               9100.0                   -7672.0
# 15                               5000.0                  -30238.0
# 16                               4000.0                  -30666.0
# 17                               2350.0                   -7758.0
#
#     profit per day  traded_rank
# 0      2736.666667            1
# 1      1828.000000            1
# 2       613.333333            8
# 3       124.000000            7
# 4     -1088.888889            9
# 5     -1790.000000            4
# 6     -3104.000000            4
# 7     -4654.545455            3
# 8     -5981.333333            6
# 9     -6450.000000            2
# 10    -6693.333333            2
# 11    -7737.142857            5
# 12    -8972.000000            6
# 13   -15516.666667            2
# 14   -19180.000000           10
# 15   -37797.500000           11
# 16   -38332.500000           11
# 17   -64650.000000            2

# %%
# Use method='spearman' for ordinal rank data
corr = df['profit per day'].corr(df['traded_rank'], method='spearman')
print(f"Spearman correlation: {corr:.3f}")
# Out:
# Spearman correlation: -0.300

# %% [markdown]
# Key Finding: A weak-to-moderate negative Spearman rank correlation ($\rho = -0.300$) exists between an item's traded rank and its profit per day. Because lower rank numbers correspond to higher trading volume (Rank 1 being the most traded), this negative correlation indicates that more frequently traded items tend to generate higher daily profits. However, since the correlation is moderate ($\rho = -0.300$), trade volume alone is not the sole driver of profitability;
